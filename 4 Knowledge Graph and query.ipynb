# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
# create a directed-graph from a dataframe
kg_csv = pd.read_csv("3_kg_df.csv")
G=nx.from_pandas_edgelist(kg_csv, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='red', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

plt.title("Knowledge graph fig 1")

image = mpimg.imread("Screenshot/KG_1.png")
plt.imshow(image)
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

plt.title("KG Fig 2")

image = mpimg.imread("Screenshot/KG_2.png")
plt.imshow(image)
plt.show()

# %% [markdown]
# # Query

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg


plt.title("Knowledge Graph query")

image = mpimg.imread("Screenshot/KG query.png")
plt.imshow(image)
plt.show()
